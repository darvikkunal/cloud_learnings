# %%
import csv

# %%
animal_csv = '/Users/darvikkunalbanda/DATA_ENGINEERING/python/data/Untitled.csv'

# %%
with open(animal_csv, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    animal_col = {'animal' : []}

    for record in reader :
        animal_col['animal'].append(record['animal'])

# %%
print(animal_col)
# Out:
# {'animal': ['Deer, white-tailed', 'Meerkat', 'Cat, civet', 'Orca', 'Gerenuk', 'Lion, stellar sea', 'Wallaby, agile', 'Kalahari scrub robin', 'Beaver, American', 'Openbill, Asian', 'Flamingo, lesser', 'Collared peccary', 'Rattlesnake, dusky', 'Lourie, grey', 'Salmon pink bird eater tarantula', 'Australian sea lion', 'Eastern fox squirrel', 'Brush-tailed phascogale', 'Numbat', 'Penguin, emperor', 'Penguin, king', 'Eagle, golden', 'Eagle, bald', 'Fox, red', 'Fox, arctic', 'Wolf, gray', 'Wolf, Arctic', 'Bear, grizzly', 'Bear, polar', 'Bear, black', 'Otter, sea', 'Otter, river', 'Seal, harbor', 'Seal, leopard', 'Dolphin, bottlenose', 'Dolphin, common', 'Shark, great white', 'Shark, tiger', 'Shark, hammerhead', 'Turtle, green', 'Turtle, loggerhead', 'Turtle, leatherback', 'Albatross, wandering', 'Albatross, black-browed', 'Gull, herring', 'Gull, ring-billed', 'Heron, great blue', 'Heron, grey', 'Stork, white', 'Crane, sandhill', 'Crane, red-crowned', 'Ibis, scarlet', 'Ibis, glossy', 'Spoon
# ...

# %%
'Pine squirrel' in animal_col['animal']
# Out:
# False
