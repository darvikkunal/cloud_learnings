# %%
import pandas as pd

# %%
records = [("Daryl", "Guillot", "dguillot0@msn.com"),
           ("Page", "Gerleit", "pgerleit1@mozilla.com"),
           ("Haven", "Hache", "hhache2@latimes.com"),
          ]
columns=["first_name", "last_name", "email"]

# %%
# METHOD 1
df=pd.DataFrame(data=records,columns=columns)
df.head()
# Out:
#   first_name last_name                  email
# 0      Daryl   Guillot      dguillot0@msn.com
# 1       Page   Gerleit  pgerleit1@mozilla.com
# 2      Haven     Hache    hhache2@latimes.com

# %%
# METHOD 2
df2 = pd.DataFrame.from_records(data=records, columns=columns, exclude=['last_name'])
df2.head()
# Out:
#   first_name                  email
# 0      Daryl      dguillot0@msn.com
# 1       Page  pgerleit1@mozilla.com
# 2      Haven    hhache2@latimes.com
