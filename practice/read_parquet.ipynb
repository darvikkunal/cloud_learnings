# %%
import pandas as pd

# %%
parquet_file = '/Users/darvikkunalbanda/DATA_ENGINEERING/python/data/parquet'

# %%
df = pd.read_parquet(parquet_file, engine='fastparquet')

# %%
df.head()
# Out:
#     registration_dttm   id first_name last_name                     email  \
# 0 2016-02-03 07:55:29  1.0     Amanda    Jordan          ajordan0@com.com
# 1 2016-02-03 17:04:03  2.0     Albert   Freeman           afreeman1@is.gd
# 2 2016-02-03 01:09:31  3.0     Evelyn    Morgan   emorgan2@altervista.org
# 3 2016-02-03 00:36:21  4.0     Denise     Riley          driley3@gmpg.org
# 4 2016-02-03 05:05:31  5.0     Carlos     Burns  cburns4@miitbeian.gov.cn
#
#    gender      ip_address                cc       country  birthdate  \
# 0  Female     1.197.201.2  6759521864920116     Indonesia   3/8/1971
# 1    Male  218.111.175.34                          Canada  1/16/1968
# 2  Female    7.161.136.94  6767119071901597        Russia   2/1/1960
# 3  Female   140.35.109.83  3576031598965625         China   4/8/1997
# 4          169.113.235.40  5602256255204850  South Africa
#
#       salary                   title comments
# 0   49756.53        Internal Auditor    1E+02
# ...

# %%
df.sort_values('first_name',ascending=False)
# Out:
#        registration_dttm     id first_name last_name                    email  \
# 1953 2016-02-03 00:38:41  954.0     Willie    Thomas  wthomasqh@earthlink.net
# 955  2016-02-03 15:15:14  956.0     Willie    Knight  wknightqj@newyorker.com
# 99   2016-02-03 15:49:55  100.0     Willie    Weaver      wweaver2r@google.de
# 634  2016-02-03 00:09:38  635.0     Willie     Dixon       wdixonhm@diigo.com
# 581  2016-02-03 03:26:08  582.0     Willie     Stone  wstoneg5@vistaprint.com
# ...                  ...    ...        ...       ...                      ...
# 2880 2016-02-03 00:21:37  881.0              Collins
# 1688 2016-02-03 23:48:25  689.0              Edwards
# 1691 2016-02-03 19:29:50  692.0                  Lee
# 1758 2016-02-03 21:37:12  759.0                Burke
# 1441 2016-02-03 16:24:44  442.0             Crawford
#
#       gender       ip_address                cc       country   birthdate  \
# 1953    Male   173.219.113.26  3560763628353111        Mexico   5/31/1990
# ...
